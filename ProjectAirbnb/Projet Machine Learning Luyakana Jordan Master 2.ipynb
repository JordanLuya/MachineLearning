# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
Biens = pd.read_csv("listings.csv") 
Reservations = pd.read_csv("calendar.csv")

# %%
Biens.shape
# Out:
# (65917, 74)

# %%
## Permet d'afficher toutes les colonnes 
pd.set_option('display.max_column',74)

# %%
Biens.head(2)
# Out:
#      id                        listing_url       scrape_id last_scraped  \
# 0  2577  https://www.airbnb.com/rooms/2577  20201214191425   2020-12-16
# 1  3109  https://www.airbnb.com/rooms/3109  20201214191425   2020-12-17
#
#                                name  \
# 0  Loft for 4 by Canal Saint Martin
# 1                      zen and calm
#
#                                          description  \
# 0  100 m2 loft (1100 sq feet) with high ceiling, ...
# 1  <b>The space</b><br />I bedroom appartment in ...
#
#                                neighborhood_overview  \
# 0                                                NaN
# 1  Good restaurants<br />very close the Montparna...
#
#                                          picture_url  host_id  \
# 0  https://a0.muscache.com/pictures/09da057c-0120...     2827
# 1  https://a0.muscache.com/pictures/baeae9e2-cd53...     3631
#
#                                  host_url host_name  host_since  \
# ...

# %%
Biens.tail(2)
# Out:
#              id                            listing_url       scrape_id  \
# 65915  47025787  https://www.airbnb.com/rooms/47025787  20201214191425
# 65916  47029229  https://www.airbnb.com/rooms/47029229  20201214191425
#
#       last_scraped                                            name  \
# 65915   2020-12-16     Chambre privée dans le salon à Paris 75019.
# 65916   2020-12-15  THE PARISIAN NEST - 3 room with balcony - 60m2
#
#                                              description  \
# 65915  Je loue une partie de mon salon qui vous sera ...
# 65916  Enjoy a truly Parisian way of life experience ...
#
#                                    neighborhood_overview  \
# 65915                                                NaN
# 65916  Down the street, there are many small boutique...
#
#                                              picture_url   host_id  \
# 65915  https://a0.muscache.com/pictures/c6f27087-3d17...  72300807
# ...

# %%
Biens.dtypes.value_counts().plot.pie(autopct='%1.1f%%')
# Out:
# <AxesSubplot:ylabel='None'>

# %%
Biens.isna()
# Out:
#           id  listing_url  scrape_id  last_scraped   name  description  \
# 0      False        False      False         False  False        False
# 1      False        False      False         False  False        False
# 2      False        False      False         False  False        False
# 3      False        False      False         False  False        False
# 4      False        False      False         False  False        False
# ...      ...          ...        ...           ...    ...          ...
# 65912  False        False      False         False  False        False
# 65913  False        False      False         False  False        False
# 65914  False        False      False         False  False        False
# 65915  False        False      False         False  False        False
# 65916  False        False      False         False  False        False
#
#        neighborhood_overview  picture_url  host_id  host_url  host_name  \
# ...

# %%
plt.figure(figsize=(20,10))
sns.heatmap(Biens.isna() , cbar=False)
# Out:
# <AxesSubplot:>

# %%
(Biens.isna().sum()/Biens.shape[0]).sort_values(ascending=False) > 0.8
# Out:
# neighbourhood_group_cleansed     True
# bathrooms                        True
# calendar_updated                 True
# license                         False
# host_response_time              False
#                                 ...
# maximum_nights                  False
# availability_30                 False
# availability_60                 False
# availability_90                 False
# id                              False
# Length: 74, dtype: bool

# %%
DataNew = Biens.copy()

# %%
DataNew = DataNew.drop(["neighbourhood_group_cleansed","bathrooms","calendar_updated"],axis=1)

# %%
DataNew.shape
# Out:
# (65917, 71)

# %%
plt.figure(figsize=(20,10))
sns.heatmap(DataNew.isna() , cbar=False)
# Out:
# <AxesSubplot:>

# %%
(DataNew.isna().sum()/DataNew.shape[0]).sort_values(ascending=False)
# Out:
# license                 0.673878
# host_response_rate      0.641580
# host_response_time      0.641580
# host_about              0.489176
# host_acceptance_rate    0.450627
#                           ...
# maximum_nights          0.000000
# availability_30         0.000000
# availability_60         0.000000
# availability_90         0.000000
# id                      0.000000
# Length: 71, dtype: float64

# %%
DataNew = DataNew.drop(["license","host_response_rate","host_response_time"],axis=1)

# %%
plt.figure(figsize=(20,10))
sns.heatmap(DataNew.isna() , cbar=False)
# Out:
# <AxesSubplot:>

# %%
(DataNew.isna().sum()/DataNew.shape[0]).sort_values(ascending=False)
# Out:
# host_about                0.489176
# host_acceptance_rate      0.450627
# neighbourhood             0.398471
# neighborhood_overview     0.398471
# review_scores_location    0.257460
#                             ...
# minimum_nights            0.000000
# maximum_nights            0.000000
# has_availability          0.000000
# availability_30           0.000000
# amenities                 0.000000
# Length: 68, dtype: float64

# %%
DataNew = DataNew.drop(["host_about","host_acceptance_rate"],axis=1)

# %%
plt.figure(figsize=(20,10))
sns.heatmap(DataNew.isna() , cbar=False)
# Out:
# <AxesSubplot:>

# %%
DataNew.head(2)
# Out:
#      id                        listing_url       scrape_id last_scraped  \
# 0  2577  https://www.airbnb.com/rooms/2577  20201214191425   2020-12-16
# 1  3109  https://www.airbnb.com/rooms/3109  20201214191425   2020-12-17
#
#                                name  \
# 0  Loft for 4 by Canal Saint Martin
# 1                      zen and calm
#
#                                          description  \
# 0  100 m2 loft (1100 sq feet) with high ceiling, ...
# 1  <b>The space</b><br />I bedroom appartment in ...
#
#                                neighborhood_overview  \
# 0                                                NaN
# 1  Good restaurants<br />very close the Montparna...
#
#                                          picture_url  host_id  \
# 0  https://a0.muscache.com/pictures/09da057c-0120...     2827
# 1  https://a0.muscache.com/pictures/baeae9e2-cd53...     3631
#
#                                  host_url host_name  host_since  \
# ...

# %%
DataNew = DataNew.drop(["listing_url","scrape_id","name","last_scraped","neighborhood_overview","picture_url","host_id","host_url","host_name","host_since","host_is_superhost","host_thumbnail_url","host_picture_url", "host_total_listings_count" , "host_verifications" , "host_has_profile_pic", "host_identity_verified" , "neighbourhood" , "bathrooms_text" , "minimum_minimum_nights" , "maximum_minimum_nights" , "minimum_maximum_nights" , "maximum_maximum_nights" , "minimum_nights_avg_ntm", "maximum_nights_avg_ntm" , "has_availability" , "calendar_last_scraped" , "number_of_reviews_ltm" , "number_of_reviews_l30d" , "first_review" , "last_review" , "review_scores_rating", "calculated_host_listings_count" , "calculated_host_listings_count_entire_homes"  , "calculated_host_listings_count_private_rooms" , "calculated_host_listings_count_shared_rooms"],axis=1)

# %%
DataNew.head(2)
# Out:
#      id                                        description  \
# 0  2577  100 m2 loft (1100 sq feet) with high ceiling, ...
# 1  3109  <b>The space</b><br />I bedroom appartment in ...
#
#                            host_location host_neighbourhood  \
# 0  Casablanca, Grand Casablanca, Morocco         République
# 1           Paris, Île-de-France, France             Alésia
#
#    host_listings_count neighbourhood_cleansed  latitude  longitude  \
# 0                  2.0               Entrepôt  48.86993    2.36251
# 1                  1.0           Observatoire  48.83349    2.31852
#
#       property_type        room_type  accommodates  bedrooms  beds  \
# 0       Entire loft  Entire home/apt             4       2.0   2.0
# 1  Entire apartment  Entire home/apt             2       NaN   1.0
#
#                                            amenities    price  minimum_nights  \
# 0  ["Dryer", "Host greets you", "Hot water", "Han...  $125.00               3
# ...

# %%
DataNew = DataNew.drop(["id" , "description", "host_location","host_listings_count","bedrooms", "amenities" , "instant_bookable" , "number_of_reviews" ] , axis=1)

# %%
DataNew.head(2)
# Out:
#   host_neighbourhood neighbourhood_cleansed  latitude  longitude  \
# 0         République               Entrepôt  48.86993    2.36251
# 1             Alésia           Observatoire  48.83349    2.31852
#
#       property_type        room_type  accommodates  beds    price  \
# 0       Entire loft  Entire home/apt             4   2.0  $125.00
# 1  Entire apartment  Entire home/apt             2   1.0   $60.00
#
#    minimum_nights  maximum_nights  availability_30  availability_60  \
# 0               3            1125               30               60
# 1               2              30                2                2
#
#    availability_90  availability_365  review_scores_accuracy  \
# 0               90               364                    10.0
# 1                2                 2                    10.0
#
#    review_scores_cleanliness  review_scores_checkin  \
# 0                       10.0                   10.0
# 1                       10.0                   10.0
#
# ...

# %%
DataNew.shape
# Out:
# (65917, 22)

# %%
DataNew = DataNew.drop(["host_neighbourhood","property_type","availability_30","availability_60"],axis=1)

# %%
DataNew.head(2)
# Out:
#   neighbourhood_cleansed  latitude  longitude        room_type  accommodates  \
# 0               Entrepôt  48.86993    2.36251  Entire home/apt             4
# 1           Observatoire  48.83349    2.31852  Entire home/apt             2
#
#    beds    price  minimum_nights  maximum_nights  availability_90  \
# 0   2.0  $125.00               3            1125               90
# 1   1.0   $60.00               2              30                2
#
#    availability_365  review_scores_accuracy  review_scores_cleanliness  \
# 0               364                    10.0                       10.0
# 1                 2                    10.0                       10.0
#
#    review_scores_checkin  review_scores_communication  review_scores_location  \
# 0                   10.0                         10.0                    10.0
# 1                   10.0                         10.0                    10.0
#
#    review_scores_value  reviews_per_month
# ...

# %%
plt.figure(figsize=(20,10))
sns.heatmap(DataNew.isna() , cbar=False)
# Out:
# <AxesSubplot:>

# %%
Data = DataNew.dropna()

# %%
plt.figure(figsize=(20,10))
sns.heatmap(Data.isna() , cbar=False)
# Out:
# <AxesSubplot:>

# %%
Data.shape
# Out:
# (48741, 18)

# %%
Data["price"].value_counts(normalize="True")
# Out:
# $60.00       0.045773
# $70.00       0.043187
# $80.00       0.042100
# $50.00       0.041772
# $90.00       0.034714
#                ...
# $492.00      0.000021
# $1,049.00    0.000021
# $749.00      0.000021
# $9,632.00    0.000021
# $448.00      0.000021
# Name: price, Length: 690, dtype: float64

# %%
Data["price"] = Data["price"].apply(lambda x : float(x.strip("$").replace(".00","").replace(",","")))
# Out:
# C:\Users\jor-l\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
plt.figure(figsize=(20,10))
sns.distplot(Data["price"],rug=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2056: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %%
Data.describe()
# Out:
#            latitude     longitude  accommodates          beds         price  \
# count  48741.000000  48741.000000  48741.000000  48741.000000  48741.000000
# mean      48.864183      2.346583      3.053200      1.671201    108.797055
# std        0.018235      0.032540      1.583506      1.357381    209.647268
# min       48.815700      2.238380      1.000000      0.000000      0.000000
# 25%       48.851030      2.326450      2.000000      1.000000     59.000000
# 50%       48.865430      2.349270      2.000000      1.000000     80.000000
# 75%       48.878900      2.371250      4.000000      2.000000    115.000000
# max       48.903800      2.471600     16.000000     90.000000  11599.000000
#
#        minimum_nights  maximum_nights  availability_90  availability_365  \
# count    48741.000000    48741.000000     48741.000000      48741.000000
# mean         5.285776      684.898012        27.809544         97.377403
# ...

# %%
plt.figure(figsize=(12,6))

sns.boxplot(x=Data.price)
plt.show()

# %%
data = Data[Data["price"] < 1000]

# %%
sns.boxplot(x=data.price)
plt.show()

# %%
data.shape
# Out:
# (48618, 18)

# %%
plt.figure(figsize=(20,10))
sns.distplot(data["price"],rug=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2056: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %%
plt.figure(figsize=(12,6))

sns.boxplot(x=data.accommodates)
plt.show()

# %%
data = data[data["accommodates"] < 10]

# %%
plt.figure(figsize=(12,6))

sns.boxplot(x=data.accommodates)
plt.show()

# %%
plt.figure(figsize=(12,6))

sns.boxplot(x=data.beds)
plt.show()

# %%
data = data[data["beds"] < 10 ]

# %%
plt.figure(figsize=(12,6))

sns.boxplot(x=data.beds)
plt.show()

# %%
plt.figure(figsize=(12,6))

sns.boxplot(x=data.maximum_nights)
plt.show()

# %%
 data = data[data["maximum_nights"] < 10000]

# %%
plt.figure(figsize=(12,6))

sns.boxplot(x=data.maximum_nights)
plt.show()

# %%
plt.figure(figsize=(12,6))

sns.boxplot(x=data.minimum_nights)
plt.show()

# %%
data = data[data["minimum_nights"] < 100]

# %%
data.describe()
# Out:
#            latitude     longitude  accommodates          beds         price  \
# count  48162.000000  48162.000000  48162.000000  48162.000000  48162.000000
# mean      48.864184      2.346630      2.997155      1.629853    100.282324
# std        0.018270      0.032568      1.424954      0.986552     77.134281
# min       48.815700      2.238380      1.000000      0.000000      0.000000
# 25%       48.851000      2.326450      2.000000      1.000000     59.000000
# 50%       48.865400      2.349290      2.000000      1.000000     80.000000
# 75%       48.878980      2.371340      4.000000      2.000000    115.000000
# max       48.903800      2.471600      9.000000      9.000000    999.000000
#
#        minimum_nights  maximum_nights  availability_90  availability_365  \
# count    48162.000000    48162.000000     48162.000000      48162.000000
# mean         4.199223      677.983618        27.535547         96.005648
# ...

# %%
## Nombre de commentaires en fonction du prix
plt.figure(figsize=(20,10))
plt.xlim((0,1))
plt.scatter(data["reviews_per_month"],data["price"])

# %%
sns.jointplot(x=data["beds"], y=data["price"], kind='scatter')

# %%
plt.figure(figsize=(20,10))
plt.scatter(data["minimum_nights"],data["price"])

# %%
plt.figure(figsize=(20,10))
plt.scatter(data["maximum_nights"],data["price"])

# %%
plt.figure(figsize=(20,10))
plt.scatter(data["review_scores_accuracy"],data["price"])

# %%
plt.figure(figsize=(20,10))
plt.scatter(data["review_scores_location"],data["price"])

# %%
data.plot.scatter(x='longitude', y='latitude', c='price', figsize=(10,10), cmap='cool', alpha=0.5);

# %%
data[data['price']<200].plot.scatter(x='longitude', y='latitude', c='price', figsize=(10,10), cmap='cool', alpha=0.5);

# %%
data.boxplot(column='price' , by='room_type' , figsize=(20,6) , rot = 90)
# Out:
# <AxesSubplot:title={'center':'price'}, xlabel='room_type'>

# %%
roomtype =  data["room_type"].value_counts()
roomtype.plot.bar()
# Out:
# <AxesSubplot:>

# %%
## Moyenne de prix par Room Type
roomtype =  data.groupby(["room_type"]).price.mean()
roomtype.plot.bar()
# Out:
# <AxesSubplot:xlabel='room_type'>

# %%
Biens["price"] = Biens["price"].apply(lambda x : float(x.strip("$").replace(".00","").replace(",","")))

# %%
## Moyenne par quartier
Biens_par_quartier = Biens.groupby(["neighbourhood_cleansed"]).price.mean()
Biens_par_quartier.plot.bar()
# Out:
# <AxesSubplot:xlabel='neighbourhood_cleansed'>

# %%
Voyageurs =  data["accommodates"].value_counts(ascending=False)
Voyageurs.plot.bar()
# Out:
# <AxesSubplot:>

# %%
#prix moyen par voyageur
prix_moyen_voyageur = data.groupby(["accommodates"]).price.mean()
prix_moyen_voyageur.plot.bar()
# Out:
# <AxesSubplot:xlabel='accommodates'>

# %%
## Prix moyen par quartier pour 2 personnes 
Prix_moyen_quartier = data[data['accommodates']==2]
Prix_moyen_quartier = data.groupby(['neighbourhood_cleansed'])['price'].mean().sort_values(ascending=True)
Prix_moyen_quartier.plot.bar()
# Out:
# <AxesSubplot:xlabel='neighbourhood_cleansed'>

# %%
Lits =  data["beds"].value_counts(ascending=False)
Lits.plot.bar()
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(20,10))
sns.distplot(Data["accommodates"])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='accommodates', ylabel='Density'>

# %% [markdown]
# ## PARTIE  MACHINE LEARNING

# %%
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet, RidgeCV, LassoCV, ElasticNetCV
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error , r2_score

# %%
dataLearning = data.copy()

# %%
dataLearning = pd.get_dummies(dataLearning)
dataLearning.head()
# Out:
#    latitude  longitude  accommodates  beds  price  minimum_nights  \
# 0  48.86993    2.36251             4   2.0  125.0               3
# 1  48.83349    2.31852             2   1.0   60.0               2
# 2  48.86409    2.35651             4   2.0   69.0               5
# 3  48.85207    2.35871             2   1.0   62.0               1
# 4  48.85758    2.35275             4   2.0   53.0              15
#
#    maximum_nights  availability_90  availability_365  review_scores_accuracy  \
# 0            1125               90               364                    10.0
# 1              30                2                 2                    10.0
# 2             120               67                67                    10.0
# 3            1125               90                90                     9.0
# 4             130               73               348                    10.0
#
#    review_scores_cleanliness  review_scores_checkin  \
# ...

# %%
dataLearning.shape
# Out:
# (48162, 40)

# %%
X = dataLearning.copy().drop('price', axis = 1)
y = dataLearning['price'].copy()

# %%
X_train_scaled
# Out:
# array([[ 1.00000000e+00,  1.23164800e+00, -3.78633386e-01, ...,
#          1.21247866e-01,  2.57856344e-02,  5.48379913e-03],
#        [ 1.00000000e+00,  3.13003041e-01, -2.20680855e+00, ...,
#          8.24756784e+00, -2.12668769e-01,  5.48379913e-03],
#        [ 1.00000000e+00,  4.27167941e-02,  7.79504465e-02, ...,
#          1.21247866e-01,  2.57856344e-02,  5.48379913e-03],
#        ...,
#        [ 1.00000000e+00,  9.65191717e-01,  7.14224089e-01, ...,
#          1.21247866e-01,  2.57856344e-02,  5.48379913e-03],
#        [ 1.00000000e+00,  7.70410535e-01,  5.47413071e-01, ...,
#          1.21247866e-01,  2.57856344e-02,  5.48379913e-03],
#        [ 1.00000000e+00,  7.98861719e-01, -7.47552277e-02, ...,
#          1.21247866e-01,  2.57856344e-02,  5.48379913e-03]])

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, y, test_size=0.25, random_state=0)

# %%
scaler = StandardScaler()
scaler.fit(X_train)
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
alphas = [1000 , 100 ,  50 , 10, 1, 0.1, 0.01]

# %%
ridge = RidgeCV(alphas=alphas)
lasso = LassoCV(alphas=alphas, max_iter=10000)
lr = LinearRegression()

# %%
for model, name in zip([lr, ridge, lasso], ['LinearRegression', 'Ridge', 'Lasso']):
    model.fit(X_train_scaled, Y_train)
    y_pred_train = model.predict(X_train_scaled)
    mse_train = mean_squared_error(y_pred=y_pred_train, y_true=Y_train)
    mrse_train = np.sqrt(mean_squared_error(y_pred=y_pred_train, y_true=Y_train))
    r2 = r2_score(Y_train,y_pred_train)
    y_pred = model.predict(X_test_scaled)
    mse_test = mean_squared_error(y_pred=y_pred, y_true=Y_test)
    mrse_test = np.sqrt(mean_squared_error(y_pred=y_pred, y_true=Y_test))
    best_alpha = ''
    if name != 'LinearRegression':
        best_alpha = ' best alpha: ' + str(model.alpha_)
    print(name + ' mrse_train: ' + str(mrse_train) + ', mrse_test: ' + str(mrse_test) + best_alpha)
    print(name + ' mse_train: ' + str(mse_train) + ', mse_test: ' + str(mse_test) + best_alpha)
    print(name + 'scoreR2: ' + str(r2))
# Out:
# LinearRegression mrse_train: 59.905964000339345, mrse_test: 59.166667434316345
# LinearRegression mse_train: 3588.7245228099537, mse_test: 3500.6945352829903
# LinearRegressionscoreR2: 0.4004512750638096
# Ridge mrse_train: 59.906242843193496, mrse_test: 59.16571377770689 best alpha: 100.0
# Ridge mse_train: 3588.757931587672, mse_test: 3500.581686825535 best alpha: 100.0
# RidgescoreR2: 0.40044569364067295
# Lasso mrse_train: 59.90602226459728, mrse_test: 59.16652759844122 best alpha: 0.01
# Lasso mse_train: 3588.731503566425, mse_test: 3500.6779880571066 best alpha: 0.01
# LassoscoreR2: 0.4004501088267205

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
pf = PolynomialFeatures(degree=2)
pf.fit(X_train_scaled)
X_train_scaled = pf.transform(X_train_scaled)
X_test_scaled = pf.transform(X_test_scaled)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-111-dead4ebfbea5> in <module>
#       1 pf = PolynomialFeatures(degree=2)
#       2 pf.fit(X_train_scaled)
# ----> 3 X_train_scaled = pf.transform(X_train_scaled)
#       4 X_test_scaled = pf.transform(X_test_scaled)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py in transform(self, X)
#    1592             else:
#    1593                 XP = np.empty((n_samples, self.n_output_features_),
# -> 1594                               dtype=X.dtype, order=self.order)
#    1595
#    1596                 # What follows is a faster implementation of:
#
# MemoryError: Unable to allocate 90.8 GiB for an array with shape (36121, 337431) and data type float64

# %%
for model, name in zip([lr, ridge, lasso], ['LinearRegression', 'Ridge', 'Lasso']):
    model.fit(X_train_scaled, Y_train)
    y_pred_train = model.predict(X_train_scaled)
    mrse_train = np.sqrt(mean_squared_error(y_pred_train,Y_train))
    y_pred = model.predict(X_test_scaled)
    r2 = r2_score(Y_train,y_pred_train)
    mrse_test = np.sqrt(mean_squared_error(y_pred,Y_test))
    mse = mean_squared_error(y_pred,Y_test)
    print(name + ' mrse_train: ' + str(mrse_train) + ', mrse_test: ' + str(mrse_test))
    print(name + ' mrse_train: ' + str(mrse_train) + ', mrse_test: ' + str(mrse_test))
    print(name + 'scoreR2: ' + str(r2))
# Out:
# LinearRegression mrse_train: 55.71624962062439, mrse_test: 56.19459333145381
# LinearRegression mrse_train: 55.71624962062439, mrse_test: 56.19459333145381
# LinearRegressionscoreR2: 0.481381371612817
# Ridge mrse_train: 55.731373135816476, mrse_test: 56.178516793628255
# Ridge mrse_train: 55.731373135816476, mrse_test: 56.178516793628255
# RidgescoreR2: 0.4810997876494636
# Lasso mrse_train: 55.9395319332911, mrse_test: 56.06401929920812
# Lasso mrse_train: 55.9395319332911, mrse_test: 56.06401929920812
# LassoscoreR2: 0.4772163246857105
